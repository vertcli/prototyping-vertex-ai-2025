# %%
from google.cloud import aiplatform
from google.cloud.aiplatform import hyperparameter_tuning as hpt

# %%
# The spec of the worker pools including machine type and Docker image
# Be sure to replace PROJECT_ID in the "image_uri" with your project.

worker_pool_specs = [{
    "machine_spec": {
        "machine_type": "n1-standard-4",
        "accelerator_type": "NVIDIA_TESLA_V100",
        "accelerator_count": 2
    },
    "replica_count": 1,
    "container_spec": {
        "image_uri": "gcr.io/uic-2025/horse-human-codelab:albert"
    }
}]

# %%
# Dictionary representing parameters to optimize.
# The dictionary key is the parameter_id, which is passed into your training
# job as a command line argument,
# And the dictionary value is the parameter specification of the metric.
parameter_spec = {
    "learning_rate": hpt.DoubleParameterSpec(min=0.001, max=1, scale="log"),
    "momentum": hpt.DoubleParameterSpec(min=0, max=1, scale="linear"),
    "num_units": hpt.DiscreteParameterSpec(values=[64, 128, 512], scale=None),
    "optimizer": hpt.CategoricalParameterSpec(values=["SGD", "ADAM"]),
}

# %%
# Dicionary representing metrics to optimize.
# The dictionary key is the metric_id, which is reported by your training job,
# And the dictionary value is the optimization goal of the metric.
metric_spec={'accuracy':'maximize'}

# %%
# Replace YOUR_BUCKET
my_custom_job = aiplatform.CustomJob(display_name='horses-humans-albert-2',
                              worker_pool_specs=worker_pool_specs,
                              staging_bucket='gs://uic-2025-hptune-bucket-albert')

# %%
hp_job = aiplatform.HyperparameterTuningJob(
    display_name='horses-humans-albert-2',
    custom_job=my_custom_job,
    metric_spec=metric_spec,
    parameter_spec=parameter_spec,
    max_trial_count=6,
    parallel_trial_count=2,
    search_algorithm=None)

hp_job.run()
# Out:
# Creating HyperparameterTuningJob
# HyperparameterTuningJob created. Resource name: projects/895139669648/locations/us-central1/hyperparameterTuningJobs/8954294208366116864
# To use this HyperparameterTuningJob in another session:
# hpt_job = aiplatform.HyperparameterTuningJob.get('projects/895139669648/locations/us-central1/hyperparameterTuningJobs/8954294208366116864')
# View HyperparameterTuningJob:
# https://console.cloud.google.com/ai/platform/locations/us-central1/training/8954294208366116864?project=895139669648
# HyperparameterTuningJob projects/895139669648/locations/us-central1/hyperparameterTuningJobs/8954294208366116864 current state:
# JobState.JOB_STATE_PENDING
# HyperparameterTuningJob projects/895139669648/locations/us-central1/hyperparameterTuningJobs/8954294208366116864 current state:
# JobState.JOB_STATE_RUNNING
# HyperparameterTuningJob projects/895139669648/locations/us-central1/hyperparameterTuningJobs/8954294208366116864 current state:
# ...
